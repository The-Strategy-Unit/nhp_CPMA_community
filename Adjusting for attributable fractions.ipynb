-- %%
--- Covert data to long format to adjust smoking USING 2023/24 DATA ONLY

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table53 AS

SELECT 
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"smoking_rate" AS rate_type,
smoking_rate AS rate_value,
obesity_rate,
alcohol_acute_rate,
alcohol_chronic_rate,
inverse_obesity_rate,
inverse_alcohol_acute_rate,
inverse_alcohol_chronic_rate,
episodes,
beddays

----FROM strategyunit.default.SLtemp_apc_mitigator_table52 
FROM strategyunit.default.SLtemp_apc_mitigator_table_over_time

UNION ALL

SELECT
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"inverse_smoking_rate" AS rate_type,
inverse_smoking_rate AS rate_value,
obesity_rate,
alcohol_acute_rate,
alcohol_chronic_rate,
inverse_obesity_rate,
inverse_alcohol_acute_rate,
inverse_alcohol_chronic_rate,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table52

-- %%
--- Adjust for smoking
CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table54 AS

SELECT *,
CASE WHEN rate_type = 'inverse_smoking_rate' THEN 0 ELSE smoking END AS smoking1,
CASE WHEN rate_type = 'inverse_smoking_rate' AND rate_value = 0 THEN episodes ELSE episodes * rate_value END AS episodes1,
CASE WHEN rate_type = 'inverse_smoking_rate' AND rate_value = 0 THEN beddays ELSE beddays * rate_value END AS beddays1

FROM strategyunit.default.SLtemp_apc_mitigator_table53 a

-- %%
--- Re group data following smoking adjustment

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table55 AS

SELECT 
a.age_range,
a.sex,
a.fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking1 as smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
a.obesity_rate,
a.alcohol_acute_rate,
a.alcohol_chronic_rate,
a.inverse_obesity_rate,
a.inverse_alcohol_acute_rate,
a.inverse_alcohol_chronic_rate,
sum(a.episodes1) AS episodes,
sum(a.beddays1) AS beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table54 a


GROUP BY

a.age_range,
a.sex,
a.fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking1,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
a.obesity_rate,
a.alcohol_acute_rate,
a.alcohol_chronic_rate,
a.inverse_obesity_rate,
a.inverse_alcohol_acute_rate,
a.inverse_alcohol_chronic_rate

-- %%
--- Covert data to long format to adjust obesity

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table56 AS

SELECT 
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"obesity_rate" AS rate_type,
obesity_rate AS rate_value,
alcohol_acute_rate,
alcohol_chronic_rate,
inverse_alcohol_acute_rate,
inverse_alcohol_chronic_rate,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table55

UNION ALL

SELECT
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"inverse_obesity_rate" AS rate_type,
inverse_obesity_rate AS rate_value,
alcohol_acute_rate,
alcohol_chronic_rate,
inverse_alcohol_acute_rate,
inverse_alcohol_chronic_rate,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table55

-- %%
--- Adjust for obesity
CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table57 AS

SELECT *,
CASE WHEN rate_type = 'inverse_obesity_rate' THEN 0 ELSE obesity_related_admissions END AS obesity_related_admissions1,
CASE WHEN rate_type = 'inverse_obesity_rate' AND rate_value = 0 THEN episodes ELSE episodes * rate_value END AS episodes1,
CASE WHEN rate_type = 'inverse_obesity_rate' AND rate_value = 0 THEN beddays ELSE beddays * rate_value END AS beddays1

FROM strategyunit.default.SLtemp_apc_mitigator_table56 a

-- %%
--- Re group data following obesity adjustment

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table58 AS

SELECT 
a.age_range,
a.sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions1 AS obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
a.alcohol_acute_rate,
a.alcohol_chronic_rate,
a.inverse_alcohol_acute_rate,
a.inverse_alcohol_chronic_rate,
sum(a.episodes1) AS episodes,
sum(a.beddays1) AS beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table57 a


GROUP BY

a.age_range,
a.sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions1,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
a.alcohol_acute_rate,
a.alcohol_chronic_rate,
a.inverse_alcohol_acute_rate,
a.inverse_alcohol_chronic_rate

-- %%
--- Covert data to long format to adjust alcohol acute

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table59 AS

SELECT 
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"alcohol_acute_rate" AS rate_type,
alcohol_acute_rate AS rate_value,
alcohol_chronic_rate,
inverse_alcohol_chronic_rate,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table58

UNION ALL

SELECT
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"inverse_alcohol_acute_rate" AS rate_type,
inverse_alcohol_acute_rate AS rate_value,
alcohol_chronic_rate,
inverse_alcohol_chronic_rate,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table58

-- %%
--- Adjust for alcohol acute
CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table60 AS

SELECT *,
CASE WHEN rate_type = 'inverse_alcohol_acute_rate' THEN 0 ELSE alcohol_partially_attributable_acute END AS alcohol_partially_attributable_acute1,
CASE WHEN rate_type = 'inverse_alcohol_acute_rate' AND rate_value = 0 THEN episodes ELSE episodes * rate_value END AS episodes1,
CASE WHEN rate_type = 'inverse_alcohol_acute_rate' AND rate_value = 0 THEN beddays ELSE beddays * rate_value END AS beddays1

FROM strategyunit.default.SLtemp_apc_mitigator_table59 a

-- %%
--- Re group data following alcohol acute adjustment

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table61 AS

SELECT 
a.age_range,
a.sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute1 AS alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
a.alcohol_chronic_rate,
a.inverse_alcohol_chronic_rate,
sum(a.episodes1) AS episodes,
sum(a.beddays1) AS beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table60 a


GROUP BY

a.age_range,
a.sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute1,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
a.alcohol_chronic_rate,
a.inverse_alcohol_chronic_rate

-- %%
--- Covert data to long format to adjust alcohol chronic

CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table62 AS

SELECT 
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"alcohol_chronic_rate" AS rate_type,
alcohol_chronic_rate AS rate_value,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table61

UNION ALL

SELECT
age_range,
sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
icb,
resladst_ons,
alcohol_partially_attributable_acute,
alcohol_partially_attributable_chronic,
alcohol_wholly_attributable,
ambulatory_care_conditions_acute,
ambulatory_care_conditions_chronic,
ambulatory_care_conditions_vaccine_preventable,
eol_care_2_days,
eol_care_3_to_14_days,
falls_related_admissions,
frail_elderly_high,
frail_elderly_intermediate,
intentional_self_harm,
medically_unexplained_related_admissions,
medicines_related_admissions_explicit,
medicines_related_admissions_implicit_anti_diabetics,
medicines_related_admissions_implicit_benzodiasepines,
medicines_related_admissions_implicit_diurectics,
medicines_related_admissions_implicit_nsaids,
obesity_related_admissions,
raid_ae,
readmission_within_28_days,
smoking,
virtual_wards_activity_avoidance_ari,
virtual_wards_activity_avoidance_heart_failure,
zero_los_no_procedure_adult,
zero_los_no_procedure_child,
emergency_elderly,
raid_ip,
stroke_early_supported_discharge,
"inverse_alcohol_chronic_rate" AS rate_type,
inverse_alcohol_chronic_rate AS rate_value,
episodes,
beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table61

-- %%
--- Adjust for alcohol chronic
CREATE OR REPLACE TABLE strategyunit.default.SLtemp_apc_mitigator_table63 AS

SELECT *,
CASE WHEN rate_type = 'inverse_alcohol_chronic_rate' THEN 0 ELSE alcohol_partially_attributable_chronic END AS alcohol_partially_attributable_chronic1,
CASE WHEN rate_type = 'inverse_alcohol_chronic_rate' AND rate_value = 0 THEN episodes ELSE episodes * rate_value END AS episodes1,
CASE WHEN rate_type = 'inverse_alcohol_chronic_rate' AND rate_value = 0 THEN beddays ELSE beddays * rate_value END AS beddays1

FROM strategyunit.default.SLtemp_apc_mitigator_table62 a

-- %%
select *
FROM strategyunit.default.SLtemp_apc_mitigator_table63
where rate_type="alcohol_chronic_rate"

-- %%
--- Summarising the episode and beddays for the mitigible activity

----CREATE OR REPLACE TABLE strategyunit.default.sl_af_describing_mitigators_final_2324 AS
CREATE OR REPLACE TABLE strategyunit.default.sl_af_describing_mitigators_final AS

SELECT 
a.age_range,
a.sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic1 AS alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(episodes1) AS episodes,
sum(beddays1) AS beddays

FROM strategyunit.default.SLtemp_apc_mitigator_table63 a


GROUP BY
a.age_range,
a.sex,
fyear,
---ethnos,
---imd19_decile,
----los_range,
---mainspef,
---tretspef,
a.icb,
a.resladst_ons,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic1,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge
