-- %%
---- Creating subset of data by AGE
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_age AS

SELECT 
a.age_range,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           age_range,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY age_range
           ) b

ON ---
a.age_range=b.age_range

LEFT JOIN (
           SELECT 
           age_range,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY age_range
           ) c

ON ---
a.age_range=c.age_range

GROUP BY 
a.age_range,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by IMD DECILE
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_imd AS

SELECT 
a.imd19_decile,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           imd19_decile,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY imd19_decile
           ) b

ON ---
a.imd19_decile=b.imd19_decile

LEFT JOIN (
           SELECT 
           imd19_decile,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY imd19_decile
           ) c

ON ---
a.imd19_decile=c.imd19_decile

GROUP BY 
a.imd19_decile,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by MAIN SPECIALTY
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_mainspef AS

SELECT 
a.mainspef,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           mainspef,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY mainspef
           ) b

ON ---
a.mainspef=b.mainspef

LEFT JOIN (
           SELECT 
           mainspef,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY mainspef
           ) c

ON ---
a.mainspef=c.mainspef

GROUP BY 
a.mainspef,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by ICB
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_icb AS

SELECT 
a.icb,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           icb,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY icb
           ) b

ON ---
a.icb=b.icb

LEFT JOIN (
           SELECT 
           icb,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY icb
           ) c

ON ---
a.icb=c.icb

GROUP BY 
a.icb,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by YEAR
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_fyear AS

SELECT 
a.fyear,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           fyear,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY fyear
           ) b

ON ---
a.fyear=b.fyear

LEFT JOIN (
           SELECT 
           fyear,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY fyear
           ) c

ON ---
a.fyear=c.fyear

GROUP BY 
a.fyear,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by LENGTH OF STAY RANGE
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_los AS

SELECT 
a.los_range,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
          los_range,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY los_range
           ) b

ON ---
a.los_range=b.los_range

LEFT JOIN (
           SELECT 
           los_range,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY los_range
           ) c

ON ---
a.los_range=c.los_range

GROUP BY 
a.los_range,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by ETHNICITY
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_ethnicity AS

SELECT 
CASE
    WHEN LEFT(a.ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(a.ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(a.ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(a.ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(a.ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END AS Ethnic_Category,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           CASE
    WHEN LEFT(ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END AS Ethnic_Category,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY CASE
    WHEN LEFT(ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END
           ) b

ON CASE
    WHEN LEFT(a.ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(a.ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(a.ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(a.ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(a.ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END = b.Ethnic_Category

LEFT JOIN (
           SELECT 
           CASE
    WHEN LEFT(ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END AS Ethnic_Category,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY CASE
    WHEN LEFT(ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END
           ) c

ON CASE
    WHEN LEFT(a.ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(a.ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(a.ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(a.ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(a.ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END = c.Ethnic_Category

GROUP BY 
CASE
    WHEN LEFT(a.ethnos, 1) IN ('A','B','C') THEN 'white'
    WHEN LEFT(a.ethnos, 1) IN ('D','E','F','G') THEN 'mixed'
    WHEN LEFT(a.ethnos, 1) IN ('H','J','K','L') THEN 'asian'
    WHEN LEFT(a.ethnos, 1) IN ('M','N','P') THEN 'black'
    WHEN LEFT(a.ethnos, 1) IN ('R','S') THEN 'other'
    ELSE NULL END,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

-- %%
---- Creating subset of data by SEX
CREATE OR REPLACE TABLE strategyunit.default.SL_AF_describing_mitigators_final_2223_sex AS

SELECT 
CASE
 WHEN a.sex = '1' THEN 'male'
 WHEN a.sex = '2' THEN 'female'
 ELSE NULL END AS sex,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
sum(a.episodes) AS episodes,
sum(a.beddays) AS beddays,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective

FROM strategyunit.default.sl_af_describing_mitigators_final_2223 a

LEFT JOIN (
           SELECT 
           sex,
           sum(total_episodes_emergency) AS total_episodes_emergency,
           sum(total_beddays_emergency) AS total_beddays_emergency
           FROM strategyunit.default.sltemp_emergency
           WHERE fyear=202223
           GROUP BY sex
           ) b

ON ---
a.sex=b.sex

LEFT JOIN (
           SELECT 
           sex,
           sum(total_episodes_elective) AS total_episodes_elective,
           sum(total_beddays_elective) AS total_beddays_elective
           FROM strategyunit.default.sltemp_elective
           WHERE fyear=202223
           GROUP BY sex
           ) c

ON ---
a.sex=c.sex

GROUP BY 
CASE
   WHEN a.sex = '1' THEN 'male'
   WHEN a.sex = '2' THEN 'female'
   ELSE NULL END,
a.alcohol_partially_attributable_acute,
a.alcohol_partially_attributable_chronic,
a.alcohol_wholly_attributable,
a.ambulatory_care_conditions_acute,
a.ambulatory_care_conditions_chronic,
a.ambulatory_care_conditions_vaccine_preventable,
a.eol_care_2_days,
a.eol_care_3_to_14_days,
a.falls_related_admissions,
a.frail_elderly_high,
a.frail_elderly_intermediate,
a.intentional_self_harm,
a.medically_unexplained_related_admissions,
a.medicines_related_admissions_explicit,
a.medicines_related_admissions_implicit_anti_diabetics,
a.medicines_related_admissions_implicit_benzodiasepines,
a.medicines_related_admissions_implicit_diurectics,
a.medicines_related_admissions_implicit_nsaids,
a.obesity_related_admissions,
a.raid_ae,
a.readmission_within_28_days,
a.smoking,
a.virtual_wards_activity_avoidance_ari,
a.virtual_wards_activity_avoidance_heart_failure,
a.zero_los_no_procedure_adult,
a.zero_los_no_procedure_child,
a.emergency_elderly,
a.raid_ip,
a.stroke_early_supported_discharge,
b.total_episodes_emergency,
b.total_beddays_emergency,
c.total_episodes_elective,
c.total_beddays_elective
